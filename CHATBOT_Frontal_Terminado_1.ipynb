# %%
import tkinter
from tkinter import *

import nltk
from nltk.stem.lancaster import LancasterStemmer #Este es un modulo que se encuentra en la libreria NLTK que nos proporciona las herramientas necesarias para el lenguaje natural
import tensorflow
import tflearn

#Agregamos dos librerias adicionales para responderle al usuario.
import random #Sirve para responder aleatoriamene cuando ya conoces la categoria a la que corresponde la frase ingresada por el usuario. 
import numpy as np
import pickle #Libreria que sirve para guardar temporales de manera permanente.

stemmer=LancasterStemmer()



#Esta funcion se encarga de convertir la frase que el usuario ingresa en 1s y 0s para luego poderla 
#ingresar al modelo de prediccion.
def bag_of_words(s, words):
    #la variable S contiene la informacion que el usuario ingresa
    #En la variable words contengo la bolsa de palabras 

    bag = [0 for _ in range(len(words))]

    #"Hola como estas, puedo reservar una cita?"
    s_words = nltk.word_tokenize(s) #Convierto la frase ingresada por el usuario en palabras 
    #["Hola", "como", "estas", "puedo", "reservar", "una", "cita"]

    s_words = [stemmer.stem(word.lower()) for word in s_words]
    #["Hola", "como", "estar", "poder", "reservar", "una", "cita"]

        #Que esta contenido en la variable words?
        #["'s", 'acceiv', 'anyon', 'ar', 'bye', 'card', 'cash', 'credit', 'day', 'de', 'do',
        #'form', 'good', 'goodby', 'hello', 'help', 'hi', 'hour', 'how', 'is', 'lat', 'mastercard', 
        #'nuev', 'on', 'op', 'salud', 'see', 'tak', 'thank', 'that', 'ther', 'today', 'up', 'what', 
        #'when', 'yo', 'you']


    for se in s_words:
        for i, w in enumerate(words):
            if w == se:
                bag[i] = 1

    return np.array(bag)


def chatbot_response(msg):


    #Esta parte del codigo sirve para cargar los datos almacenados en el archivo intents.json
    #Recordar: El archivo .json es la base de datos inicial con la cual se alimentará el sistema 
    # y en el cual se pueden agregar nuevas formas de saludar, responder, categorias etc. 
    import json
    with open('intents(Hackers Girls).json') as file:
        data = json.load(file)

    #Con el bloque siguiente lo que hacemos es obtener cada una de las palabras que tenemos en el 
    #archivo .json y convertirlas en el lenguaje natural, adicionalmente obtengo las catergorias. 


    try:
        with open("data.pickle", "rb") as f:
            words, labels, training, output = pickle.load(f)

        model.load("model.tflearn")       

    except:

        #En caso de un error se ejectuta por aqui. 

        words=[] #Palabras sin deferenciar la frase a la que pertenecen 
        labels=[] #Titulos, legendas.
        docs_x=[]
        docs_y=[]

        #Con este ciclo for estoy recorriendo todo el archivo json y tomando cada una de las frases para 
        #convertirlas en palabras. 

        #Con ese for llenare la variable que guarda las palabra
        for intents in data['intents']:
            for patterns in intents['patterns']:
                wrds = nltk.word_tokenize(patterns) #Convierte una frase a un conjunto de palabras
                words.extend(wrds)
                docs_x.append(wrds)
                docs_y.append(intents['tag'])


                if intents['tag'] not in labels:
                    labels.append(intents['tag'])       

        #La informacion y los codigos contenidos en esta celda sirven para recorrer todas las palabras extraidas
        #del archivo .json y convertirlas en el lenguaje natural. Adicionalmente con la funcion list y sorted 
        #logramos eliminar las palabras repetidas y ordenarlas. 
        words=[stemmer.stem(w.lower()) for w in words if w != "?"]

        words = sorted(list(set(words))) #Organizando el conjunto de paralabras de forma no repetiva y ordenada.

        labels = sorted(labels)

        print (labels)

        #['greeting', 'goodbye', 'thanks', 'hours', 'payments', 'opentoday']


        #A continuacion se crean dos variables llamadas training y output

        #Deben asemejar a training con las palabras osea words.
        #Deben asemejar a output con las categorias osea labels.

        training=[]
        output=[]

        out_empty = [0 for _ in range (len(labels))]

        #print (out_empty)

        #Este ciclo for se encarga de analizar todas y cada una de las palabras en todas y cada una de las frases


        for x, doc in enumerate(docs_x):
            bag = []

            wrds=[stemmer.stem(w.lower()) for w in doc]

            for w in words:
                if w in wrds:
                    #print ("Entre por UNO")
                    #print ("Este es w")
                    #print (w)
                    #print ("Este es wrds")
                    #print (wrds)
                    #print ("Este es words")
                    #print (words)
                    bag.append(1)
                else:

                    #print ("Entre por DOS")
                    #print ("Este es w")
                    #print (w)
                    #print ("Este es wrds")
                    #print (wrds)
                    #print ("Este es words")
                    #print (words)
                    bag.append(0)

                output_row = out_empty[:]
                output_row[labels.index(docs_y[x])] = 1

                training.append(bag)
                output.append(output_row)



        #Todo el codigo anterior es necesario para llegar a las dos 
        #variables "Finales" que alimentaran el sistema de machine
        #Learning llamadas training y output las cuales formaran 
        #parte de la capa de alimentacion. 

        training = np.array(training) #Contiene la informacion preparada con la cual se va a alimentar el sistema referentes a las palabras
        output = np.array(output) #Contiene la informacion preparada con la cual se va a alimentar el sistema referente a la categorizacion

        with open ("data.pickle", "wb") as f:
            pickle.dump((words, labels, training, output), f)        

        #tensorflow.reset_default_graph() #Es la primera vez que utilizo la libreria tensorflow en el codigo y estoy utilizando
        #una funcion de esa libreria llamada reset_default_graph

        tensorflow.compat.v1.reset_default_graph()

        #Con esta linea estoy creando mi primera capa o capa 0 o capa de alimentacion
        net = tflearn.input_data(shape=[None, len(training[0])]) 


        #Con esta linea estoy creando mi primera capa de red neuronal Circulos negros
        net = tflearn.fully_connected(net, 8)


        #Con esta linea estoy creando mi segunda capa de red neuronal Circulos rojos
        net = tflearn.fully_connected(net, 8)


        #Continuacion 
        #Capa de decisión Circulos verdes

        #Otro modelo de regresion es sigmoid
        net = tflearn.fully_connected(net, len(output[0]), activation="softmax")
        net = tflearn.regression(net)

        #Esta linea se encarga de construir el modelo final a partir de las especificaciones anteriores
        model = tflearn.DNN(net)

        try:
            model.load("model.tflearn")
        except:       

            #Hasta el momento hemos configurado nuestro modelo, es hora de entrenarlo con nuestros datos. 
            #Para eso usaremos las siguientes lineas de codigo

            model.fit(training, output, n_epoch=1000, batch_size=8, show_metric=True)
            model.save("model.tflearn")


        #Que esta contenido en la variable words?
        #["'s", 'acceiv', 'anyon', 'ar', 'bye', 'card', 'cash', 'credit', 'day', 'de', 'do',
        #'form', 'good', 'goodby', 'hello', 'help', 'hi', 'hour', 'how', 'is', 'lat', 'mastercard', 
        #'nuev', 'on', 'op', 'salud', 'see', 'tak', 'thank', 'that', 'ther', 'today', 'up', 'what', 
        #'when', 'yo', 'you']
        #En la variable msg contengo la frase que el usuario ingresa.

        results = model.predict([bag_of_words(msg, words)])           

        results_index = np.argmax(results) #La funcion argmax obtiene la probabilidad mas alta.

        tag = labels[results_index]

        #Finalmente ingreso al archivo json particularmente a la categoria elegida por el modelo
        #y me quedo con las respuestas correspondientes. 
        for tg in data["intents"]:
            if tg['tag'] == tag:
                responses = tg['responses']

        #escogemos una respuesta al azar
        return (random.choice(responses))
        

#Aqui empieza la parte VISUAL

base = Tk()
base.title("Chatbot de Viajes")
base.geometry("400x480")

def send():
    msg=EntryBox.get("1.0", 'end-1c').strip()
    EntryBox.delete("0.0", END)
    
    if msg != '':
        ChatLog.config(state=NORMAL)       
        ChatLog.insert(END, "You: "+msg+'\n\n')
        ChatLog.config(foreground="black", font=("Verdana",12)) 
        
        res = chatbot_response(msg)
        ChatLog.insert(END, "Summer: "+res+'\n\n')
        ChatLog.config(state=DISABLED)
        ChatLog.yview(END)
        
    

#Con esta linea estoy limitando la geometria de la ventana
#Al cambiar los False por True habilito la redimension en alguno de las direcciones 
base.resizable(width=FALSE, height=FALSE)


#Con esta linea estoy creando el cuadro blanco donde se imprimen los mensajes
#Hace referencia al historial de los mensajes. 
ChatLog = Text(base, bd=0, bg="white", height="30", width="80", font="Arial")
ChatLog.config(foreground="black", font=("Verdana", 12))

#Inserto el primer mensaje que debe contener este recuadro
ChatLog.insert(END, "BIENVENIDO A TUS VACACIONES"+'\n\n'+"My name is summer and I will help you choose your best vacation "+'\n\n')
ChatLog.place(x=6, y=6, height=280, width=370)

ChatLog.insert(END, "En que podemos ayurte?" +'\n'+ "1. Hotels."'\n' "2. transportation." '\n' "3. hours." '\n' "4. location." '\n' "5. opentoday." '\n' "6. payments." '\n')
ChatLog.place(x=6, y=6, height=280, width=370)

scrollbar = Scrollbar(base, command=ChatLog.yview, cursor = "heart")
ChatLog['yscrollcommand']=scrollbar.set
scrollbar.place(x=376, y=8, height=370)
ChatLog.config(state=DISABLED)

EntryBox=Text(base, bd=0, bg="white", width="80", height="30", font="Arial")
EntryBox.place(x=10, y=401, height=65, width=285)#6,401,90,265.

SendButton = Button(base, font=("Verdana", 12, 'bold'), text="Send", width="9",
                   height=6, bd=0, bg="blue", activebackground="pink", 
                    fg='#ffffff', command=send)
SendButton.place(x=282, y=401, height=65)

    
base.mainloop()
# Out:
# [' Decameron packets', 'Decameron', 'goodbye', 'greeting', 'hotel options', 'hours', 'location', 'opentoday', 'payments', 'thanks', 'transportation']
# INFO:tensorflow:Restoring parameters from C:\Users\yazir\model.tflearn
# ---------------------------------
# Run id: HBNAYC
# Log directory: /tmp/tflearn_logs/
# INFO:tensorflow:Summary name Accuracy/ (raw) is illegal; using Accuracy/__raw_ instead.
# ---------------------------------
# Training samples: 3196
# Validation samples: 0
# --
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\yazir\AppData\Local\Temp\ipykernel_4600\748390485.py", line 66, in chatbot_response
#     model.load("model.tflearn")
# UnboundLocalError: local variable 'model' referenced before assignment
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\yazir\anaconda3\lib\site-packages\tensorflow\python\client\session.py", line 1378, in _do_call
#     return fn(*args)
#   File "C:\Users\yazir\anaconda3\lib\site-packages\tensorflow\python\client\session.py", line 1361, in _run_fn
#     return self._call_tf_sessionrun(options, feed_dict, fetch_list,
#   File "C:\Users\yazir\anaconda3\lib\site-packages\tensorflow\python\client\session.py", line 1454, in _call_tf_sessionrun
#     return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
# tensorflow.python.framework.errors_impl.InvalidArgumentError: Assign requires shapes of both tensors to match. lhs shape= [68,8] rhs shape= [66,8]
# 	 [[{{node save_1/Assign_4}}]]
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\yazir\anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 1415, in restore
#     sess.run(self.saver_def.restore_op_name,
#   File "C:\Users\yazir\anaconda3\lib\site-packages\tensorflow\python\client\session.py", line 968, in run
#     result = self._run(None, fetches, feed_dict, options_ptr,
#   File "C:\Users\yazir\anaconda3\lib\site-packages\tensorflow\python\client\session.py", line 1191, in _run
#     results = self._do_run(handle, final_targets, final_fetches,
#   File "C:\Users\yazir\anaconda3\lib\site-packages\tensorflow\python\client\session.py", line 1371, in _do_run
#     return self._do_call(_run_fn, feeds, fetches, targets, options,
#   File "C:\Users\yazir\anaconda3\lib\site-packages\tensorflow\python\client\session.py", line 1397, in _do_call
#     raise type(e)(node_def, op, message)  # pylint: disable=no-value-for-parameter
# tensorflow.python.framework.errors_impl.InvalidArgumentError: Graph execution error:
#
# Detected at node 'save_1/Assign_4' defined at (most recent call last):
#     File "C:\Users\yazir\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "C:\Users\yazir\anaconda3\lib\runpy.py", line 87, in _run_code
#       exec(code, run_globals)
#     File "C:\Users\yazir\anaconda3\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "C:\Users\yazir\anaconda3\lib\site-packages\traitlets\config\application.py", line 846, in launch_instance
#       app.start()
#     File "C:\Users\yazir\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 712, in start
#       self.io_loop.start()
#     File "C:\Users\yazir\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#       self.asyncio_loop.run_forever()
#     File "C:\Users\yazir\anaconda3\lib\asyncio\base_events.py", line 601, in run_forever
#       self._run_once()
#     File "C:\Users\yazir\anaconda3\lib\asyncio\base_events.py", line 1905, in _run_once
#       handle._run()
#     File "C:\Users\yazir\anaconda3\lib\asyncio\events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "C:\Users\yazir\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 510, in dispatch_queue
#       await self.process_one()
#     File "C:\Users\yazir\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 499, in process_one
#       await dispatch(*args)
#     File "C:\Users\yazir\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 406, in dispatch_shell
#       await result
#     File "C:\Users\yazir\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 730, in execute_request
#       reply_content = await reply_content
#     File "C:\Users\yazir\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 390, in do_execute
#       res = shell.run_cell(code, store_history=store_history, silent=silent)
#     File "C:\Users\yazir\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 528, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "C:\Users\yazir\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2914, in run_cell
#       result = self._run_cell(
#     File "C:\Users\yazir\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2960, in _run_cell
#       return runner(coro)
#     File "C:\Users\yazir\anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 78, in _pseudo_sync_runner
#       coro.send(None)
#     File "C:\Users\yazir\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3185, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "C:\Users\yazir\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#       if (await self.run_code(code, result,  async_=asy)):
#     File "C:\Users\yazir\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "C:\Users\yazir\AppData\Local\Temp\ipykernel_4600\748390485.py", line 280, in <module>
#       base.mainloop()
#     File "C:\Users\yazir\anaconda3\lib\tkinter\__init__.py", line 1429, in mainloop
#       self.tk.mainloop(n)
#     File "C:\Users\yazir\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#       return self.func(*args)
#     File "C:\Users\yazir\AppData\Local\Temp\ipykernel_4600\748390485.py", line 242, in send
#       res = chatbot_response(msg)
#     File "C:\Users\yazir\AppData\Local\Temp\ipykernel_4600\748390485.py", line 191, in chatbot_response
#       model = tflearn.DNN(net)
#     File "C:\Users\yazir\anaconda3\lib\site-packages\tflearn\models\dnn.py", line 57, in __init__
#       self.trainer = Trainer(self.train_ops,
#     File "C:\Users\yazir\anaconda3\lib\site-packages\tflearn\helpers\trainer.py", line 149, in __init__
#       self.restorer = tf.train.Saver(
# Node: 'save_1/Assign_4'
# Assign requires shapes of both tensors to match. lhs shape= [68,8] rhs shape= [66,8]
# 	 [[{{node save_1/Assign_4}}]]
#
# Original stack trace for 'save_1/Assign_4':
#   File "C:\Users\yazir\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\yazir\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\yazir\anaconda3\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\yazir\anaconda3\lib\site-packages\traitlets\config\application.py", line 846, in launch_instance
#     app.start()
#   File "C:\Users\yazir\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "C:\Users\yazir\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\yazir\anaconda3\lib\asyncio\base_events.py", line 601, in run_forever
#     self._run_once()
#   File "C:\Users\yazir\anaconda3\lib\asyncio\base_events.py", line 1905, in _run_once
#     handle._run()
#   File "C:\Users\yazir\anaconda3\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\yazir\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\yazir\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "C:\Users\yazir\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "C:\Users\yazir\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\yazir\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 390, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\yazir\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\yazir\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2914, in run_cell
#     result = self._run_cell(
#   File "C:\Users\yazir\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2960, in _run_cell
#     return runner(coro)
#   File "C:\Users\yazir\anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\yazir\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3185, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\yazir\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\yazir\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\yazir\AppData\Local\Temp\ipykernel_4600\748390485.py", line 280, in <module>
#     base.mainloop()
#   File "C:\Users\yazir\anaconda3\lib\tkinter\__init__.py", line 1429, in mainloop
#     self.tk.mainloop(n)
#   File "C:\Users\yazir\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\Users\yazir\AppData\Local\Temp\ipykernel_4600\748390485.py", line 242, in send
#     res = chatbot_response(msg)
#   File "C:\Users\yazir\AppData\Local\Temp\ipykernel_4600\748390485.py", line 191, in chatbot_response
#     model = tflearn.DNN(net)
#   File "C:\Users\yazir\anaconda3\lib\site-packages\tflearn\models\dnn.py", line 57, in __init__
#     self.trainer = Trainer(self.train_ops,
#   File "C:\Users\yazir\anaconda3\lib\site-packages\tflearn\helpers\trainer.py", line 149, in __init__
#     self.restorer = tf.train.Saver(
#   File "C:\Users\yazir\anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 931, in __init__
#     self.build()
#   File "C:\Users\yazir\anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 943, in build
#     self._build(self._filename, build_save=True, build_restore=True)
#   File "C:\Users\yazir\anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 971, in _build
#     self.saver_def = self._builder._build_internal(  # pylint: disable=protected-access
#   File "C:\Users\yazir\anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 540, in _build_internal
#     restore_op = self._AddRestoreOps(filename_tensor, saveables,
#   File "C:\Users\yazir\anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 383, in _AddRestoreOps
#     assign_ops.append(saveable.restore(saveable_tensors, shapes))
#   File "C:\Users\yazir\anaconda3\lib\site-packages\tensorflow\python\training\saving\saveable_object_util.py", line 83, in restore
#     return state_ops.assign(
#   File "C:\Users\yazir\anaconda3\lib\site-packages\tensorflow\python\ops\state_ops.py", line 352, in assign
#     return gen_state_ops.assign(
#   File "C:\Users\yazir\anaconda3\lib\site-packages\tensorflow\python\ops\gen_state_ops.py", line 61, in assign
#     _, _, _op, _outputs = _op_def_library._apply_op_helper(
#   File "C:\Users\yazir\anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 795, in _apply_op_helper
#     op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#   File "C:\Users\yazir\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 3798, in _create_op_internal
#     ret = Operation(
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\yazir\AppData\Local\Temp\ipykernel_4600\748390485.py", line 194, in chatbot_response
#     model.load("model.tflearn")
#   File "C:\Users\yazir\anaconda3\lib\site-packages\tflearn\models\dnn.py", line 302, in load
#     self.trainer.restore(model_file, weights_only, **optargs)
#   File "C:\Users\yazir\anaconda3\lib\site-packages\tflearn\helpers\trainer.py", line 500, in restore
#     self.restorer.restore(self.session, model_file)
#   File "C:\Users\yazir\anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 1451, in restore
#     raise _wrap_restore_error_with_msg(
# tensorflow.python.framework.errors_impl.InvalidArgumentError: Restoring from checkpoint failed. This is most likely due to a mismatch between the current graph and the graph from the checkpoint. Please ensure that you have not altered the graph expected based on the checkpoint. Original error:
#
# Graph execution error:
#
# Detected at node 'save_1/Assign_4' defined at (most recent call last):
#     File "C:\Users\yazir\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "C:\Users\yazir\anaconda3\lib\runpy.py", line 87, in _run_code
#       exec(code, run_globals)
#     File "C:\Users\yazir\anaconda3\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "C:\Users\yazir\anaconda3\lib\site-packages\traitlets\config\application.py", line 846, in launch_instance
#       app.start()
#     File "C:\Users\yazir\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 712, in start
#       self.io_loop.start()
#     File "C:\Users\yazir\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#       self.asyncio_loop.run_forever()
#     File "C:\Users\yazir\anaconda3\lib\asyncio\base_events.py", line 601, in run_forever
#       self._run_once()
#     File "C:\Users\yazir\anaconda3\lib\asyncio\base_events.py", line 1905, in _run_once
#       handle._run()
#     File "C:\Users\yazir\anaconda3\lib\asyncio\events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "C:\Users\yazir\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 510, in dispatch_queue
#       await self.process_one()
#     File "C:\Users\yazir\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 499, in process_one
#       await dispatch(*args)
#     File "C:\Users\yazir\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 406, in dispatch_shell
#       await result
#     File "C:\Users\yazir\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 730, in execute_request
#       reply_content = await reply_content
#     File "C:\Users\yazir\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 390, in do_execute
#       res = shell.run_cell(code, store_history=store_history, silent=silent)
#     File "C:\Users\yazir\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 528, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "C:\Users\yazir\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2914, in run_cell
#       result = self._run_cell(
#     File "C:\Users\yazir\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2960, in _run_cell
#       return runner(coro)
#     File "C:\Users\yazir\anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 78, in _pseudo_sync_runner
#       coro.send(None)
#     File "C:\Users\yazir\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3185, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "C:\Users\yazir\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#       if (await self.run_code(code, result,  async_=asy)):
#     File "C:\Users\yazir\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "C:\Users\yazir\AppData\Local\Temp\ipykernel_4600\748390485.py", line 280, in <module>
#       base.mainloop()
#     File "C:\Users\yazir\anaconda3\lib\tkinter\__init__.py", line 1429, in mainloop
#       self.tk.mainloop(n)
#     File "C:\Users\yazir\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#       return self.func(*args)
#     File "C:\Users\yazir\AppData\Local\Temp\ipykernel_4600\748390485.py", line 242, in send
#       res = chatbot_response(msg)
#     File "C:\Users\yazir\AppData\Local\Temp\ipykernel_4600\748390485.py", line 191, in chatbot_response
#       model = tflearn.DNN(net)
#     File "C:\Users\yazir\anaconda3\lib\site-packages\tflearn\models\dnn.py", line 57, in __init__
#       self.trainer = Trainer(self.train_ops,
#     File "C:\Users\yazir\anaconda3\lib\site-packages\tflearn\helpers\trainer.py", line 149, in __init__
#       self.restorer = tf.train.Saver(
# Node: 'save_1/Assign_4'
# Assign requires shapes of both tensors to match. lhs shape= [68,8] rhs shape= [66,8]
# 	 [[{{node save_1/Assign_4}}]]
#
# Original stack trace for 'save_1/Assign_4':
#   File "C:\Users\yazir\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\yazir\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\yazir\anaconda3\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\yazir\anaconda3\lib\site-packages\traitlets\config\application.py", line 846, in launch_instance
#     app.start()
#   File "C:\Users\yazir\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "C:\Users\yazir\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\yazir\anaconda3\lib\asyncio\base_events.py", line 601, in run_forever
#     self._run_once()
#   File "C:\Users\yazir\anaconda3\lib\asyncio\base_events.py", line 1905, in _run_once
#     handle._run()
#   File "C:\Users\yazir\anaconda3\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\yazir\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\yazir\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "C:\Users\yazir\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "C:\Users\yazir\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\yazir\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 390, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\yazir\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\yazir\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2914, in run_cell
#     result = self._run_cell(
#   File "C:\Users\yazir\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2960, in _run_cell
#     return runner(coro)
#   File "C:\Users\yazir\anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\yazir\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3185, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\yazir\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\yazir\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\yazir\AppData\Local\Temp\ipykernel_4600\748390485.py", line 280, in <module>
#     base.mainloop()
#   File "C:\Users\yazir\anaconda3\lib\tkinter\__init__.py", line 1429, in mainloop
#     self.tk.mainloop(n)
#   File "C:\Users\yazir\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\Users\yazir\AppData\Local\Temp\ipykernel_4600\748390485.py", line 242, in send
#     res = chatbot_response(msg)
#   File "C:\Users\yazir\AppData\Local\Temp\ipykernel_4600\748390485.py", line 191, in chatbot_response
#     model = tflearn.DNN(net)
#   File "C:\Users\yazir\anaconda3\lib\site-packages\tflearn\models\dnn.py", line 57, in __init__
#     self.trainer = Trainer(self.train_ops,
#   File "C:\Users\yazir\anaconda3\lib\site-packages\tflearn\helpers\trainer.py", line 149, in __init__
#     self.restorer = tf.train.Saver(
#   File "C:\Users\yazir\anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 931, in __init__
#     self.build()
#   File "C:\Users\yazir\anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 943, in build
#     self._build(self._filename, build_save=True, build_restore=True)
#   File "C:\Users\yazir\anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 971, in _build
#     self.saver_def = self._builder._build_internal(  # pylint: disable=protected-access
#   File "C:\Users\yazir\anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 540, in _build_internal
#     restore_op = self._AddRestoreOps(filename_tensor, saveables,
#   File "C:\Users\yazir\anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 383, in _AddRestoreOps
#     assign_ops.append(saveable.restore(saveable_tensors, shapes))
#   File "C:\Users\yazir\anaconda3\lib\site-packages\tensorflow\python\training\saving\saveable_object_util.py", line 83, in restore
#     return state_ops.assign(
#   File "C:\Users\yazir\anaconda3\lib\site-packages\tensorflow\python\ops\state_ops.py", line 352, in assign
#     return gen_state_ops.assign(
#   File "C:\Users\yazir\anaconda3\lib\site-packages\tensorflow\python\ops\gen_state_ops.py", line 61, in assign
#     _, _, _op, _outputs = _op_def_library._apply_op_helper(
#   File "C:\Users\yazir\anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 795, in _apply_op_helper
#     op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#   File "C:\Users\yazir\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 3798, in _create_op_internal
#     ret = Operation(
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\yazir\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\Users\yazir\AppData\Local\Temp\ipykernel_4600\748390485.py", line 242, in send
#     res = chatbot_response(msg)
#   File "C:\Users\yazir\AppData\Local\Temp\ipykernel_4600\748390485.py", line 200, in chatbot_response
#     model.fit(training, output, n_epoch=1000, batch_size=8, show_metric=True)
#   File "C:\Users\yazir\anaconda3\lib\site-packages\tflearn\models\dnn.py", line 196, in fit
#     self.trainer.fit(feed_dicts, val_feed_dicts=val_feed_dicts,
#   File "C:\Users\yazir\anaconda3\lib\site-packages\tflearn\helpers\trainer.py", line 341, in fit
#     snapshot = train_op._train(self.training_state.step,
#   File "C:\Users\yazir\anaconda3\lib\site-packages\tflearn\helpers\trainer.py", line 826, in _train
#     tflearn.is_training(True, session=self.session)
#   File "C:\Users\yazir\anaconda3\lib\site-packages\tflearn\config.py", line 95, in is_training
#     tf.get_collection('is_training_ops')[0].eval(session=session)
#   File "C:\Users\yazir\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 991, in eval
#     return _eval_using_default_session(self, feed_dict, self.graph, session)
#   File "C:\Users\yazir\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 5798, in _eval_using_default_session
#     return session.run(tensors, feed_dict)
#   File "C:\Users\yazir\anaconda3\lib\site-packages\tensorflow\python\client\session.py", line 968, in run
#     result = self._run(None, fetches, feed_dict, options_ptr,
#   File "C:\Users\yazir\anaconda3\lib\site-packages\tensorflow\python\client\session.py", line 1116, in _run
#     raise RuntimeError('Attempted to use a closed Session.')
# RuntimeError: Attempted to use a closed Session.

# %%
pip install instabot
# Out:
# Collecting instabotNote: you may need to restart the kernel to use updated packages.
#
#   Downloading instabot-0.117.0.tar.gz (84 kB)
#      -------------------------------------- 84.4/84.4 kB 394.3 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: certifi>=2019.11.28 in c:\users\yazir\anaconda3\lib\site-packages (from instabot) (2022.9.14)
# Requirement already satisfied: chardet>=3.0.4 in c:\users\yazir\anaconda3\lib\site-packages (from instabot) (4.0.0)
# Requirement already satisfied: future>=0.18.2 in c:\users\yazir\anaconda3\lib\site-packages (from instabot) (0.18.2)
# Collecting huepy>=1.2.1
#   Downloading huepy-1.2.1.tar.gz (15 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: idna>=2.8 in c:\users\yazir\anaconda3\lib\site-packages (from instabot) (3.3)
# Requirement already satisfied: pysocks>=1.7.1 in c:\users\yazir\anaconda3\lib\site-packages (from instabot) (1.7.1)
# Requirement already satisfied: pytz>=2019.3 in c:\users\yazir\anaconda3\lib\site-packages (from instabot) (2022.1)
# Requirement already satisfied: requests>=2.22.0 in c:\users\yazir\anaconda3\lib\site-packages (from instabot) (2.28.1)
# Collecting requests-toolbelt>=0.9.1
#   Downloading requests_toolbelt-0.10.1-py2.py3-none-any.whl (54 kB)
#      -------------------------------------- 54.5/54.5 kB 702.9 kB/s eta 0:00:00
# Collecting responses>=0.10.9
#   Downloading responses-0.22.0-py3-none-any.whl (51 kB)
#      ---------------------------------------- 51.1/51.1 kB 2.7 MB/s eta 0:00:00
# Collecting schedule>=0.6.0
#   Downloading schedule-1.1.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: six>=1.14.0 in c:\users\yazir\anaconda3\lib\site-packages (from instabot) (1.16.0)
# Requirement already satisfied: tqdm>=4.41.1 in c:\users\yazir\anaconda3\lib\site-packages (from instabot) (4.64.1)
# Requirement already satisfied: urllib3>=1.25.7 in c:\users\yazir\anaconda3\lib\site-packages (from instabot) (1.26.11)
# Requirement already satisfied: mock>=3.0.5 in c:\users\yazir\anaconda3\lib\site-packages (from instabot) (4.0.3)
# Collecting moviepy>=1.0.1
#   Downloading moviepy-1.0.3.tar.gz (388 kB)
#      ------------------------------------ 388.3/388.3 kB 756.1 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: Pillow>=6.2.2 in c:\users\yazir\anaconda3\lib\site-packages (from instabot) (9.2.0)
# Requirement already satisfied: pytest>=4.6.9 in c:\users\yazir\anaconda3\lib\site-packages (from instabot) (7.1.2)
# Collecting decorator<5.0,>=4.0.2
#   Downloading decorator-4.4.2-py2.py3-none-any.whl (9.2 kB)
# Collecting proglog<=1.0.0
#   Downloading proglog-0.1.10-py3-none-any.whl (6.1 kB)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\yazir\anaconda3\lib\site-packages (from moviepy>=1.0.1->instabot) (1.21.5)
# Requirement already satisfied: imageio<3.0,>=2.5 in c:\users\yazir\anaconda3\lib\site-packages (from moviepy>=1.0.1->instabot) (2.19.3)
# Collecting imageio_ffmpeg>=0.2.0
#   Downloading imageio_ffmpeg-0.4.8-py3-none-win_amd64.whl (22.6 MB)
#      ---------------------------------------- 22.6/22.6 MB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=19.2.0 in c:\users\yazir\anaconda3\lib\site-packages (from pytest>=4.6.9->instabot) (21.4.0)
# Requirement already satisfied: iniconfig in c:\users\yazir\anaconda3\lib\site-packages (from pytest>=4.6.9->instabot) (1.1.1)
# Requirement already satisfied: packaging in c:\users\yazir\anaconda3\lib\site-packages (from pytest>=4.6.9->instabot) (21.3)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\users\yazir\anaconda3\lib\site-packages (from pytest>=4.6.9->instabot) (1.0.0)
# Requirement already satisfied: py>=1.8.2 in c:\users\yazir\anaconda3\lib\site-packages (from pytest>=4.6.9->instabot) (1.11.0)
# Requirement already satisfied: tomli>=1.0.0 in c:\users\yazir\anaconda3\lib\site-packages (from pytest>=4.6.9->instabot) (2.0.1)
# Requirement already satisfied: atomicwrites>=1.0 in c:\users\yazir\anaconda3\lib\site-packages (from pytest>=4.6.9->instabot) (1.4.0)
# Requirement already satisfied: colorama in c:\users\yazir\anaconda3\lib\site-packages (from pytest>=4.6.9->instabot) (0.4.5)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\yazir\anaconda3\lib\site-packages (from requests>=2.22.0->instabot) (2.0.4)
# Collecting types-toml
#   Downloading types_toml-0.10.8.1-py3-none-any.whl (4.5 kB)
# Requirement already satisfied: toml in c:\users\yazir\anaconda3\lib\site-packages (from responses>=0.10.9->instabot) (0.10.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\yazir\anaconda3\lib\site-packages (from packaging->pytest>=4.6.9->instabot) (3.0.9)
# Building wheels for collected packages: instabot, huepy, moviepy
#   Building wheel for instabot (setup.py): started
#   Building wheel for instabot (setup.py): finished with status 'done'
#   Created wheel for instabot: filename=instabot-0.117.0-py3-none-any.whl size=101265 sha256=234547f17433dba6f26e004e8f752d9ce09927e35810093de0692411c1b97bcb
#   Stored in directory: c:\users\yazir\appdata\local\pip\cache\wheels\80\07\61\54956f1f5ea9ba62c092445004593c58669515d7c1903300c0
#   Building wheel for huepy (setup.py): started
#   Building wheel for huepy (setup.py): finished with status 'done'
#   Created wheel for huepy: filename=huepy-1.2.1-py3-none-any.whl size=26983 sha256=8287215a6339e660f506717cc4cd3c6a1bef4d756b11b8ca36627f8cd2f7c51a
#   Stored in directory: c:\users\yazir\appdata\local\pip\cache\wheels\4c\92\02\33d3191c5ddcd442bdcecc6a9e8d74eb2ceda0fa9abb0e9cab
#   Building wheel for moviepy (setup.py): started
#   Building wheel for moviepy (setup.py): finished with status 'done'
#   Created wheel for moviepy: filename=moviepy-1.0.3-py3-none-any.whl size=110728 sha256=2a50176e58a31b25b3d39f14a1d12173a24af1dc0dca6f8e3a44ac4726057214
#   Stored in directory: c:\users\yazir\appdata\local\pip\cache\wheels\29\15\e4\4f790bec6acd51a00b67e8ee1394f0bc6e0135c315f8ff399a
# Successfully built instabot huepy moviepy
# Installing collected packages: types-toml, huepy, schedule, imageio_ffmpeg, decorator, responses, requests-toolbelt, proglog, moviepy, instabot
#   Attempting uninstall: decorator
#     Found existing installation: decorator 5.1.1
#     Uninstalling decorator-5.1.1:
#       Successfully uninstalled decorator-5.1.1
# Successfully installed decorator-4.4.2 huepy-1.2.1 imageio_ffmpeg-0.4.8 instabot-0.117.0 moviepy-1.0.3 proglog-0.1.10 requests-toolbelt-0.10.1 responses-0.22.0 schedule-1.1.0 types-toml-0.10.8.1
